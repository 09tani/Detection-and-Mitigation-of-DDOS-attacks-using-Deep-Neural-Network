# %% [markdown]
# # Import important Libaries

# %%
# cd Desktop/Nottingham/3rd/Dissertation/Code/Comp3003
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import graphviz

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import CategoricalNB
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.decomposition import PCA
from sklearn.tree import export_graphviz

from mlxtend.plotting import plot_decision_regions
from six import StringIO
from IPython.display import Image

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
# Out:
# 2025-03-01 15:47:32.339847: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('selected_features.csv')
df.head(10)
# Out:
#    Dst Port  Flow Duration     Flow Pkts/s  Fwd Header Len  Bwd Header Len  \
# 0      3389        1270037       11.810680             172             152
# 1       443       16053698        1.183528             232             172
# 2        21              2  1000000.000000              40              20
# 3     57936             33    60606.060606              40               0
# 4        53          14695      136.100715               8               8
# 5       443       88113985        0.374515             352             428
# 6        53           2244      891.265597               8               8
# 7        21              2  1000000.000000              40              20
# 8        80       49824355        0.341199             172             240
# 9        80             87    22988.505747              40               0
#
#       Fwd Pkts/s     Bwd Pkts/s  PSH Flag Cnt  Init Fwd Win Byts  \
# 0       6.299029       5.511650             1               8192
# 1       0.685200       0.498328             1               8192
# 2  500000.000000  500000.000000             1              26883
# 3   60606.060606       0.000000             0                260
# 4      68.050357      68.050357             0                 -1
# 5       0.192932       0.181583             1               8192
# 6     445.632799     445.632799             0                 -1
# 7  500000.000000  500000.000000             1              26883
# 8       0.160564       0.180635             1               8192
# 9   22988.505747       0.000000             0                278
#
#    Fwd Act Data Pkts  Label
# 0                  5      0
# 1                  5      0
# 2                  0      1
# 3                  0      0
# 4                  0      0
# 5                 11      0
# 6                  0      0
# 7                  0      1
# 8                  5      0
# 9                  0      0

# %% [markdown]
# Taking a look at how much data I have to work with.

# %%
print("This Dataset has {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# This Dataset has 34477 rows and 11 columns

# %% [markdown]
# Checking that I have all the important col.

# %%
df.columns
# Out:
# Index(['Dst Port', 'Flow Duration', 'Flow Pkts/s', 'Fwd Header Len',
#        'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'PSH Flag Cnt',
#        'Init Fwd Win Byts', 'Fwd Act Data Pkts', 'Label'],
#       dtype='object')

# %%
print(df.nunique())
# Out:
# Dst Port              2342
# Flow Duration        16870
# Flow Pkts/s          17576
# Fwd Header Len         248
# Bwd Header Len         353
# Fwd Pkts/s           17489
# Bwd Pkts/s           15783
# PSH Flag Cnt             2
# Init Fwd Win Byts      500
# Fwd Act Data Pkts       46
# Label                    3
# dtype: int64

# %% [markdown]
# Finding the unique value of each col.

# %%
df_cleaned = df[(df >= 0).all(axis=1)]

# %% [markdown]
# ### Spliting target variable from features

# %%
#separating input and output variables
x = df_cleaned.drop(['Label'], axis=1)
y = df_cleaned['Label']
print(x)
# Out:
#        Dst Port  Flow Duration     Flow Pkts/s  Fwd Header Len  \
# 0          3389        1270037       11.810680             172
# 1           443       16053698        1.183528             232
# 2            21              2  1000000.000000              40
# 3         57936             33    60606.060606              40
# 5           443       88113985        0.374515             352
# ...         ...            ...             ...             ...
# 34471        80       53229595        0.037573              40
# 34472       443            556     5395.683453              60
# 34474        80        5894605        1.357173              92
# 34475        21              2  1000000.000000              40
# 34476        21              2  1000000.000000              40
#
#        Bwd Header Len     Fwd Pkts/s     Bwd Pkts/s  PSH Flag Cnt  \
# 0                 152       6.299029       5.511650             1
# 1                 172       0.685200       0.498328             1
# 2                  20  500000.000000  500000.000000             1
# 3                   0   60606.060606       0.000000             0
# 5                 428       0.192932       0.181583             1
# ...               ...            ...            ...           ...
# 34471               0       0.037573       0.000000             0
# 34472               0    5395.683453       0.000000             0
# 34474              92       0.678587       0.678587             1
# 34475              20  500000.000000  500000.000000             1
# 34476              20  500000.000000  500000.000000             1
#
#        Init Fwd Win Byts  Fwd Act Data Pkts
# 0                   8192                  5
# 1                   8192                  5
# 2                  26883                  0
# 3                    260                  0
# 5                   8192                 11
# ...                  ...                ...
# 34471                279                  0
# 34472                251                  1
# 34474               8192                  1
# 34475              26883                  0
# 34476              26883                  0
#
# [27938 rows x 10 columns]

# %% [markdown]
# ### Normalising Variables

# %%
# ms = MinMaxScaler()
# x = ms.fit_transform(x)
#original minmax is found not suitable for my dataset a new normalisation method is needed. 

# scaler = StandardScaler()
# df_cleaned = scaler.fit_transform(df_cleaned)
# print(df_cleaned)

# Scalling was attempted but considering attributes like port number

# %% [markdown]
# ### Split DS
# 70% training 30% rest
# 15% valid 15% test

# %%
# Split the data into training (70%) and temporary (30%)
train_df, val_test_df = train_test_split(x, test_size=0.3, random_state=21)

# Split the temporary data into validation and testing (15% each)
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=21)

print(f"Training set: {len(train_df)} rows")
print(f"Validation set: {len(val_df)} rows")
print(f"Testing set: {len(test_df)} rows")
# Out:
# Training set: 19556 rows
# Validation set: 4191 rows
# Testing set: 4191 rows

# %% [markdown]
# # BASELINE CLASSIFIERS
#
# - Kth Nearest Neighbour.
#
# - DNN (Deep NN)
#
# - SVM
# - Decision tree
# - Naive Bayes
# - Quadratic Discriminant Analaysis
# - SGD
# - Logistic Regression
# - XGBoost

# %%
Classifier_accuracy = []

# %% [markdown]
# ### K-Nearest Neighbor Classifier

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y)
y_pred = knn_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of KNN Classifier : %.2f" % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 knn_clf = KNeighborsClassifier()
# ----> 2 knn_clf.fit(X_train, y_train)
#       3 y_pred = knn_clf.predict(X_test)
#       4 accuracy = metrics.accuracy_score(y_test, y_pred)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# ### Defining the Deep Neural Network

# %%
# Define and compile model
model = keras.Sequential()
model.add(Dense(28 , input_shape=(10,) , activation="relu" , name="Hidden_Layer_1"))
model.add(Dense(10 , activation="relu" , name="Hidden_Layer_2"))
model.add(Dense(3, activation="softmax", name="Output_Layer")) 
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer=opt, loss="sparse_categorical_crossentropy", metrics=['accuracy'])
model.summary()

# %% [markdown]
# ### Model Fitting

# %%
# fit model
history_org = model.fit(
    X_train, 
    y_train, 
    batch_size=32, 
    epochs=100, verbose=2, 
    # 要跑多少遍你就调epochs
    callbacks=None, 
    validation_data=(X_test,y_test), 
    shuffle=True, 
    class_weight=None, 
    sample_weight=None, 
    initial_epoch=0)

# %% [markdown]
# ### Plotting Loss v/s Epochs

# %%
loss = history_org.history['loss']
val_loss = history_org.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g', label = 'Training Loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
plt.title('Loss v/s No. of epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting Accuracy v/s Epochs

# %%
loss = history_org.history['accuracy']
val_loss = history_org.history['val_accuracy']
plt.plot(epochs, loss, 'g', label = 'Training accuracy')
plt.plot(epochs, val_loss, 'r', label = 'Validation accuracy')
plt.title('Accuracy Scores v/s Number of Epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy of Deep neural Network : %.2f' % (accuracy*100))
Classifier_accuracy.append(accuracy*100)

# %% [markdown]
# ### Model Evaluation

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy of Deep neural Network : %.2f' % (accuracy*100))
Classifier_accuracy.append(accuracy*100)

# %% [markdown]
# ### SVM

# %%
svc_clf = SVC() 
svc_clf.fit(X_train,y_train)
y_pred = svc_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of SVM Classifier : %.2f" % (accuracy*100) )

# %% [markdown]
# ### Decision Tree Classifier

# %%
dt_clf = DecisionTreeClassifier(max_depth=5)
dt_clf.fit(X_train,y_train)
y_pred = dt_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Decision Tree Classifier : %.2f" % (accuracy*100) )

# %% [markdown]
# ### Naive Bayes Classifier

# %% [markdown]
# Due to Naive Bayes incompatability with negative values. "Init Fwd Win Byts" have been dropped

# %%
X_train_NB = X_train.drop["Init Fwd Win Byts"]

# %%
nb_clf = CategoricalNB()
nb_clf.fit(X_train,y_train)
y_pred = nb_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Naive Bayes Classifier : %.2f" % (accuracy*100) )

# %%
print(np.any(X_train < 0))
print(X_train)

# %%
	
Stochastic Gradient Classifier

# %%
sgd_clf=SGDClassifier(loss="hinge", penalty="l2")
sgd_clf.fit(X_train,y_train)
y_pred=sgd_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of SGD Classifier : %.2f" % (accuracy*100))

# %%
Logistic Regression

# %%
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)
y_pred=lr_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Logistic Regression Classifier : %.2f" % (accuracy*100))

# %%
XGBoost Classifier

# %%
xgb_clf=xgb.XGBClassifier(eval_metric = 'error',objective='binary:logistic',max_depth=2, learning_rate=0.1)
xgb_clf.fit(X_train,y_train)
y_pred=xgb_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of XGBoost Classifier : %.2f" % (accuracy*100))

# %%
Comparitive analysis of models

# %%
Classifier_names = ["DNN", "KNN", "RBF_SVM", "Decision Tree","Naive Bayes","Quadratic","SGD","Logistic Regression","XGBoost"]

# %%
df_clf = pd.DataFrame()
df_clf['name'] = Classifier_names
df_clf['Accuracy'] = Classifier_accuracy
df_clf = df_clf.sort_values(by=['Accuracy'], ascending=False)
df_clf.head(10)

# %%
Visualize accuracies of the models

# %%
sns.set(style="whitegrid",rc={'figure.figsize':(7,7)})
ax = sns.barplot(y="name", x="Accuracy", data=df_clf)

# %%
print(f"The best baseline Classifier is {df_clf.name[0]} with an accuracy of {df_clf.Accuracy[0]}.")

# %%
Hyperparameter tuning
