# %% [markdown]
# # Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import KNNImputer

# %% [markdown]
# ### Compass
# Definition
# - Protocol Number 6 = TCP
# - Protocol Number 17 = UDP

# %% [markdown]
# # Read in Dataset

# %%
original_df = pd.read_csv('sampled_data.csv')
original_df.head()
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0       443         6  14/02/2018 12:41:31      116087899            21
# 1        21         6  14/02/2018 11:13:32              1             1
# 2      3389         6  14/02/2018 02:34:56        1206036             8
# 3        53        17  14/02/2018 03:56:36           1273             1
# 4        21         6  14/02/2018 11:01:12              2             1
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0            19              750             5575              381
# 1             1                0                0                0
# 2             7             1148             1581              677
# 3             1               32               76               32
# 4             1                0                0                0
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min   Active Mean    Active Std  \
# 0                0  ...                20  20977.833333  37055.338921
# 1                0  ...                40      0.000000      0.000000
# 2                0  ...                20      0.000000      0.000000
# 3               32  ...                 8      0.000000      0.000000
# 4                0  ...                40      0.000000      0.000000
#
#    Active Max  Active Min     Idle Mean      Idle Std  Idle Max  Idle Min  \
# 0      138644       10179  9.653011e+06  1.202897e+06  10005066   5833596
# 1           0           0  0.000000e+00  0.000000e+00         0         0
# 2           0           0  0.000000e+00  0.000000e+00         0         0
# 3           0           0  0.000000e+00  0.000000e+00         0         0
# 4           0           0  0.000000e+00  0.000000e+00         0         0
#
#             Label
# 0          Benign
# 1  FTP-BruteForce
# 2          Benign
# 3          Benign
# 4  FTP-BruteForce
#
# [5 rows x 80 columns]

# %% [markdown]
# --------
# # Date preparation

# %%
print("This Dataset has {} rows and {} columns".format(original_df.shape[0], original_df.shape[1]))
# Out:
# This Dataset has 50000 rows and 80 columns

# %%
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 80 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           50000 non-null  int64
#  1   Protocol           50000 non-null  int64
#  2   Timestamp          50000 non-null  object
#  3   Flow Duration      50000 non-null  int64
#  4   Tot Fwd Pkts       50000 non-null  int64
#  5   Tot Bwd Pkts       50000 non-null  int64
#  6   TotLen Fwd Pkts    50000 non-null  int64
#  7   TotLen Bwd Pkts    50000 non-null  int64
#  8   Fwd Pkt Len Max    50000 non-null  int64
#  9   Fwd Pkt Len Min    50000 non-null  int64
#  10  Fwd Pkt Len Mean   50000 non-null  float64
#  11  Fwd Pkt Len Std    50000 non-null  float64
#  12  Bwd Pkt Len Max    50000 non-null  int64
#  13  Bwd Pkt Len Min    50000 non-null  int64
#  14  Bwd Pkt Len Mean   50000 non-null  float64
#  15  Bwd Pkt Len Std    50000 non-null  float64
#  16  Flow Byts/s        49886 non-null  float64
#  17  Flow Pkts/s        50000 non-null  float64
#  18  Flow IAT Mean      50000 non-null  float64
#  19  Flow IAT Std       50000 non-null  float64
#  20  Flow IAT Max       50000 non-null  int64
#  21  Flow IAT Min       50000 non-null  int64
#  22  Fwd IAT Tot        50000 non-null  int64
#  23  Fwd IAT Mean       50000 non-null  float64
#  24  Fwd IAT Std        50000 non-null  float64
#  25  Fwd IAT Max        50000 non-null  int64
#  26  Fwd IAT Min        50000 non-null  int64
#  27  Bwd IAT Tot        50000 non-null  int64
#  28  Bwd IAT Mean       50000 non-null  float64
#  29  Bwd IAT Std        50000 non-null  float64
#  30  Bwd IAT Max        50000 non-null  int64
#  31  Bwd IAT Min        50000 non-null  int64
#  32  Fwd PSH Flags      50000 non-null  int64
#  33  Bwd PSH Flags      50000 non-null  int64
#  34  Fwd URG Flags      50000 non-null  int64
#  35  Bwd URG Flags      50000 non-null  int64
#  36  Fwd Header Len     50000 non-null  int64
#  37  Bwd Header Len     50000 non-null  int64
#  38  Fwd Pkts/s         50000 non-null  float64
#  39  Bwd Pkts/s         50000 non-null  float64
#  40  Pkt Len Min        50000 non-null  int64
#  41  Pkt Len Max        50000 non-null  int64
#  42  Pkt Len Mean       50000 non-null  float64
#  43  Pkt Len Std        50000 non-null  float64
#  44  Pkt Len Var        50000 non-null  float64
#  45  FIN Flag Cnt       50000 non-null  int64
#  46  SYN Flag Cnt       50000 non-null  int64
#  47  RST Flag Cnt       50000 non-null  int64
#  48  PSH Flag Cnt       50000 non-null  int64
#  49  ACK Flag Cnt       50000 non-null  int64
#  50  URG Flag Cnt       50000 non-null  int64
#  51  CWE Flag Count     50000 non-null  int64
#  52  ECE Flag Cnt       50000 non-null  int64
#  53  Down/Up Ratio      50000 non-null  int64
#  54  Pkt Size Avg       50000 non-null  float64
#  55  Fwd Seg Size Avg   50000 non-null  float64
#  56  Bwd Seg Size Avg   50000 non-null  float64
#  57  Fwd Byts/b Avg     50000 non-null  int64
#  58  Fwd Pkts/b Avg     50000 non-null  int64
#  59  Fwd Blk Rate Avg   50000 non-null  int64
#  60  Bwd Byts/b Avg     50000 non-null  int64
#  61  Bwd Pkts/b Avg     50000 non-null  int64
#  62  Bwd Blk Rate Avg   50000 non-null  int64
#  63  Subflow Fwd Pkts   50000 non-null  int64
#  64  Subflow Fwd Byts   50000 non-null  int64
#  65  Subflow Bwd Pkts   50000 non-null  int64
#  66  Subflow Bwd Byts   50000 non-null  int64
#  67  Init Fwd Win Byts  50000 non-null  int64
#  68  Init Bwd Win Byts  50000 non-null  int64
#  69  Fwd Act Data Pkts  50000 non-null  int64
#  70  Fwd Seg Size Min   50000 non-null  int64
#  71  Active Mean        50000 non-null  float64
#  72  Active Std         50000 non-null  float64
#  73  Active Max         50000 non-null  int64
#  74  Active Min         50000 non-null  int64
#  75  Idle Mean          50000 non-null  float64
#  76  Idle Std           50000 non-null  float64
#  77  Idle Max           50000 non-null  int64
#  78  Idle Min           50000 non-null  int64
#  79  Label              50000 non-null  object
# dtypes: float64(24), int64(54), object(2)
# memory usage: 30.5+ MB

# %% [markdown]
# Note there are 2 object features here and to create the machine learning models later they have to be converted to ints or floats.

# %% [markdown]
# ### Drop timestap object column
# Can't be coverted to meaningful trainning feature.

# %%
train_df = original_df.drop("Timestamp", axis='columns')

# %% [markdown]
# ### Convert target from object to norminal data

# %%
print(train_df["Label"].dtype)
print(train_df["Label"].unique())
# Out:
# object
# ['Benign' 'FTP-BruteForce' 'SSH-Bruteforce']

# %%
train_df["Label"] = train_df["Label"].map({"Benign": 0, "FTP-BruteForce": 1, "SSH-Bruteforce": 2})

# %% [markdown]
# ---
# Finding numbers that are too large for float64

# %% [markdown]
# Select only numeric columns

# %%
numeric_df = train_df.select_dtypes(include=[np.number])

# %% [markdown]
# Check for infinite values in numeric columns

# %%
has_inf = np.isinf(numeric_df).any().any()
print("Contains infinite values:", has_inf)
# Out:
# Contains infinite values: True

# %% [markdown]
# Replace the infinite values in numeric columns with nan

# %%
train_df[numeric_df.columns] = numeric_df.replace([np.inf, -np.inf], np.nan)

# %% [markdown]
# ## Indentifying missing values

# %%
print(train_df.isna())
# Out:
#        Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# 0         False     False          False         False         False
# 1         False     False          False         False         False
# 2         False     False          False         False         False
# 3         False     False          False         False         False
# 4         False     False          False         False         False
# ...         ...       ...            ...           ...           ...
# 49995     False     False          False         False         False
# 49996     False     False          False         False         False
# 49997     False     False          False         False         False
# 49998     False     False          False         False         False
# 49999     False     False          False         False         False
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# 0                False            False            False            False
# 1                False            False            False            False
# 2                False            False            False            False
# 3                False            False            False            False
# 4                False            False            False            False
# ...                ...              ...              ...              ...
# 49995            False            False            False            False
# 49996            False            False            False            False
# 49997            False            False            False            False
# 49998            False            False            False            False
# 49999            False            False            False            False
#
#        Fwd Pkt Len Mean  ...  Fwd Seg Size Min  Active Mean  Active Std  \
# 0                 False  ...             False        False       False
# 1                 False  ...             False        False       False
# 2                 False  ...             False        False       False
# 3                 False  ...             False        False       False
# 4                 False  ...             False        False       False
# ...                 ...  ...               ...          ...         ...
# 49995             False  ...             False        False       False
# 49996             False  ...             False        False       False
# 49997             False  ...             False        False       False
# 49998             False  ...             False        False       False
# 49999             False  ...             False        False       False
#
#        Active Max  Active Min  Idle Mean  Idle Std  Idle Max  Idle Min  Label
# 0           False       False      False     False     False     False  False
# 1           False       False      False     False     False     False  False
# 2           False       False      False     False     False     False  False
# 3           False       False      False     False     False     False  False
# 4           False       False      False     False     False     False  False
# ...           ...         ...        ...       ...       ...       ...    ...
# 49995       False       False      False     False     False     False  False
# 49996       False       False      False     False     False     False  False
# 49997       False       False      False     False     False     False  False
# 49998       False       False      False     False     False     False  False
# 49999       False       False      False     False     False     False  False
#
# [50000 rows x 79 columns]

# %%
missing_values = train_df.isnull().sum()
# Filter out columns with null values
lis = missing_values[missing_values > 0]  
print(lis)
# Out:
# Flow Byts/s    201
# Flow Pkts/s    201
# dtype: int64

# %% [markdown]
# ---
# ## Data Imputation
# Using KNN to fill missing data for flow byts.

# %%
knn_imputer = KNNImputer(n_neighbors=5)

# %%
cols_with_missing = lis.index

# %% [markdown]
# Applying KNN

# %%
train_df[cols_with_missing] = knn_imputer.fit_transform(train_df[cols_with_missing])
train_df_clean = train_df

# %% [markdown]
# ---
# ### Checking for data bias

# %%
malign = train_df_clean[train_df_clean['Label'].isin([1, 2])]
benign = train_df_clean[train_df_clean['Label'] == 0]

print('Number of DDOS attacks that has occured :',round((len(malign)/train_df_clean.shape[0])*100,2),'%')
print('Number of DDOS attacks that has not occured :',round((len(benign)/train_df_clean.shape[0])*100,2),'%')
# Out:
# Number of DDOS attacks that has occured : 38.6 %
# Number of DDOS attacks that has not occured : 61.4 %

# %% [markdown]
# ### Visualising bias

# %%
# Let's plot the Label class against the Frequency
labels = ['benign','FTP-BruteForce','SSH-Bruteforce']
classes = pd.value_counts(train_df['Label'], sort = True) / train_df['Label'].count() *100
classes.plot(kind = 'bar')
plt.title("Label class distribution")
plt.xticks(range(3), labels , rotation=0)
plt.xlabel("Label")
plt.ylabel("Frequency %")
# Out:
# /var/folders/4m/g_6893ld36vbb7dxvkc930h00000gp/T/ipykernel_18843/4010626481.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   classes = pd.value_counts(train_df['Label'], sort = True) / train_df['Label'].count() *100
# Text(0, 0.5, 'Frequency %')

# %% [markdown]
# Note the dataset is extremly bias. The ML can be used to indetify, when an attack is happening. and if luckly it's a ftp or ssh brute force. Which currently no Ml sepcify in this detection.
#
# Most algo i read abt. is a general detection model but to better work with Fail2ban's jailing system, anti brute force detection a new ML detector is needed hence this project.

# %% [markdown]
# Pairplot of:
#     Dst Port (Destination port)
#     Protocol
#     Flow Duration
#     Tot Fwd Pkts (Total forward packets)
#     Tot Bwd Pkts (Total backward packets)
#     Label (Target)
# which are the important feature based on Kaggle, the source of the Data.

# %%
print(train_df_clean['Protocol'].unique())
# Out:
# [ 6 17  0]

# %% [markdown]
# - 6 = TCP
# - 17 = UDP
# - At this point no further information is gather about IP 0 therefore rows with 0 would be taken as N.A. and be dropped.
# - More reading have been done and Protocol 0 refers to HOPOPT which is a technique linked to IPV6.
# - Given that IPV6 would likely have better solutions to DDOS attacks this ML would not cover this area.

# %%
train_df_clean_dropIP = train_df_clean[train_df_clean['Protocol'] != 0]
print(train_df_clean_dropIP['Protocol'].unique())
# Out:
# [ 6 17]

# %%
sns.pairplot(train_df_clean_dropIP,hue="Label",vars=['Protocol','Dst Port','Flow Duration'])

# %%
train_df_clean_dropIP.columns
# Out:
# Index(['Dst Port', 'Protocol', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
#        'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std',
#        'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean',
#        'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot',
#        'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min',
#        'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max',
#        'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags',
#        'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s',
#        'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean',
#        'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt',
#        'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt',
#        'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg',
#        'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg',
#        'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg',
#        'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Subflow Fwd Pkts',
#        'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts',
#        'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts',
#        'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max',
#        'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label'],
#       dtype='object')

# %% [markdown]
# there are currently too many cols. therefore an random forest selection is used to pick out the top 30

# %%
train_df_clean_dropIP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49434 entries, 0 to 49999
# Data columns (total 79 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           49434 non-null  int64
#  1   Protocol           49434 non-null  int64
#  2   Flow Duration      49434 non-null  int64
#  3   Tot Fwd Pkts       49434 non-null  int64
#  4   Tot Bwd Pkts       49434 non-null  int64
#  5   TotLen Fwd Pkts    49434 non-null  int64
#  6   TotLen Bwd Pkts    49434 non-null  int64
#  7   Fwd Pkt Len Max    49434 non-null  int64
#  8   Fwd Pkt Len Min    49434 non-null  int64
#  9   Fwd Pkt Len Mean   49434 non-null  float64
#  10  Fwd Pkt Len Std    49434 non-null  float64
#  11  Bwd Pkt Len Max    49434 non-null  int64
#  12  Bwd Pkt Len Min    49434 non-null  int64
#  13  Bwd Pkt Len Mean   49434 non-null  float64
#  14  Bwd Pkt Len Std    49434 non-null  float64
#  15  Flow Byts/s        49434 non-null  float64
#  16  Flow Pkts/s        49434 non-null  float64
#  17  Flow IAT Mean      49434 non-null  float64
#  18  Flow IAT Std       49434 non-null  float64
#  19  Flow IAT Max       49434 non-null  int64
#  20  Flow IAT Min       49434 non-null  int64
#  21  Fwd IAT Tot        49434 non-null  int64
#  22  Fwd IAT Mean       49434 non-null  float64
#  23  Fwd IAT Std        49434 non-null  float64
#  24  Fwd IAT Max        49434 non-null  int64
#  25  Fwd IAT Min        49434 non-null  int64
#  26  Bwd IAT Tot        49434 non-null  int64
#  27  Bwd IAT Mean       49434 non-null  float64
#  28  Bwd IAT Std        49434 non-null  float64
#  29  Bwd IAT Max        49434 non-null  int64
#  30  Bwd IAT Min        49434 non-null  int64
#  31  Fwd PSH Flags      49434 non-null  int64
#  32  Bwd PSH Flags      49434 non-null  int64
#  33  Fwd URG Flags      49434 non-null  int64
#  34  Bwd URG Flags      49434 non-null  int64
#  35  Fwd Header Len     49434 non-null  int64
#  36  Bwd Header Len     49434 non-null  int64
#  37  Fwd Pkts/s         49434 non-null  float64
#  38  Bwd Pkts/s         49434 non-null  float64
#  39  Pkt Len Min        49434 non-null  int64
#  40  Pkt Len Max        49434 non-null  int64
#  41  Pkt Len Mean       49434 non-null  float64
#  42  Pkt Len Std        49434 non-null  float64
#  43  Pkt Len Var        49434 non-null  float64
#  44  FIN Flag Cnt       49434 non-null  int64
#  45  SYN Flag Cnt       49434 non-null  int64
#  46  RST Flag Cnt       49434 non-null  int64
#  47  PSH Flag Cnt       49434 non-null  int64
#  48  ACK Flag Cnt       49434 non-null  int64
#  49  URG Flag Cnt       49434 non-null  int64
#  50  CWE Flag Count     49434 non-null  int64
#  51  ECE Flag Cnt       49434 non-null  int64
#  52  Down/Up Ratio      49434 non-null  int64
#  53  Pkt Size Avg       49434 non-null  float64
#  54  Fwd Seg Size Avg   49434 non-null  float64
#  55  Bwd Seg Size Avg   49434 non-null  float64
#  56  Fwd Byts/b Avg     49434 non-null  int64
#  57  Fwd Pkts/b Avg     49434 non-null  int64
#  58  Fwd Blk Rate Avg   49434 non-null  int64
#  59  Bwd Byts/b Avg     49434 non-null  int64
#  60  Bwd Pkts/b Avg     49434 non-null  int64
#  61  Bwd Blk Rate Avg   49434 non-null  int64
#  62  Subflow Fwd Pkts   49434 non-null  int64
#  63  Subflow Fwd Byts   49434 non-null  int64
#  64  Subflow Bwd Pkts   49434 non-null  int64
#  65  Subflow Bwd Byts   49434 non-null  int64
#  66  Init Fwd Win Byts  49434 non-null  int64
#  67  Init Bwd Win Byts  49434 non-null  int64
#  68  Fwd Act Data Pkts  49434 non-null  int64
#  69  Fwd Seg Size Min   49434 non-null  int64
#  70  Active Mean        49434 non-null  float64
#  71  Active Std         49434 non-null  float64
#  72  Active Max         49434 non-null  int64
#  73  Active Min         49434 non-null  int64
#  74  Idle Mean          49434 non-null  float64
#  75  Idle Std           49434 non-null  float64
#  76  Idle Max           49434 non-null  int64
#  77  Idle Min           49434 non-null  int64
#  78  Label              49434 non-null  int64
# dtypes: float64(24), int64(55)
# memory usage: 30.2 MB

# %% [markdown]
# Features such as mean, averages, max and min are causing problems with the random forest therefore it will be deleted.

# %%
# Drop columns containing 'Mean', 'Std', 'Min', or 'Max'
columns_to_drop = [col for col in train_df_clean_dropIP.columns if any(x in col for x in ["Mean", "Std", "Min", "Max","Avg"])]
train_df_clean_stats = train_df_clean_dropIP.drop(columns=columns_to_drop)

print("Remaining Columns:", train_df_clean_stats.columns)
# Out:
# Remaining Columns: Index(['Dst Port', 'Protocol', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Flow Byts/s', 'Flow Pkts/s',
#        'Fwd IAT Tot', 'Bwd IAT Tot', 'Fwd PSH Flags', 'Bwd PSH Flags',
#        'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len',
#        'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Var', 'FIN Flag Cnt',
#        'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt',
#        'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio',
#        'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts',
#        'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts',
#        'Fwd Act Data Pkts', 'Label'],
#       dtype='object')

# %%
train_df_clean_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49434 entries, 0 to 49999
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           49434 non-null  int64
#  1   Protocol           49434 non-null  int64
#  2   Flow Duration      49434 non-null  int64
#  3   Tot Fwd Pkts       49434 non-null  int64
#  4   Tot Bwd Pkts       49434 non-null  int64
#  5   TotLen Fwd Pkts    49434 non-null  int64
#  6   TotLen Bwd Pkts    49434 non-null  int64
#  7   Flow Byts/s        49434 non-null  float64
#  8   Flow Pkts/s        49434 non-null  float64
#  9   Fwd IAT Tot        49434 non-null  int64
#  10  Bwd IAT Tot        49434 non-null  int64
#  11  Fwd PSH Flags      49434 non-null  int64
#  12  Bwd PSH Flags      49434 non-null  int64
#  13  Fwd URG Flags      49434 non-null  int64
#  14  Bwd URG Flags      49434 non-null  int64
#  15  Fwd Header Len     49434 non-null  int64
#  16  Bwd Header Len     49434 non-null  int64
#  17  Fwd Pkts/s         49434 non-null  float64
#  18  Bwd Pkts/s         49434 non-null  float64
#  19  Pkt Len Var        49434 non-null  float64
#  20  FIN Flag Cnt       49434 non-null  int64
#  21  SYN Flag Cnt       49434 non-null  int64
#  22  RST Flag Cnt       49434 non-null  int64
#  23  PSH Flag Cnt       49434 non-null  int64
#  24  ACK Flag Cnt       49434 non-null  int64
#  25  URG Flag Cnt       49434 non-null  int64
#  26  CWE Flag Count     49434 non-null  int64
#  27  ECE Flag Cnt       49434 non-null  int64
#  28  Down/Up Ratio      49434 non-null  int64
#  29  Subflow Fwd Pkts   49434 non-null  int64
#  30  Subflow Fwd Byts   49434 non-null  int64
#  31  Subflow Bwd Pkts   49434 non-null  int64
#  32  Subflow Bwd Byts   49434 non-null  int64
#  33  Init Fwd Win Byts  49434 non-null  int64
#  34  Init Bwd Win Byts  49434 non-null  int64
#  35  Fwd Act Data Pkts  49434 non-null  int64
#  36  Label              49434 non-null  int64
# dtypes: float64(5), int64(32)
# memory usage: 14.3 MB

# %%
print(train_df_clean_stats.iloc[:, [7, 16, 17, 18]])
# Out:
#         Flow Byts/s  Bwd Header Len      Fwd Pkts/s      Bwd Pkts/s
# 0         54.484576             524        0.180897        0.163669
# 1          0.000000              20  1000000.000000  1000000.000000
# 2       2262.784859             152        6.633301        5.804139
# 3      84838.963079               8      785.545954      785.545954
# 4          0.000000              20   500000.000000   500000.000000
# ...             ...             ...             ...             ...
# 49995  10969.735404              72       53.971638       40.478728
# 49996   1265.559151             192        0.969989        1.247129
# 49997  11830.554926             648       61.818706       51.515589
# 49998    510.304625             152        1.876810        1.313767
# 49999      0.000000              20  1000000.000000  1000000.000000
#
# [49434 rows x 4 columns]

# %% [markdown]
# ---
# ## Feature Selection

# %% [markdown]
# PCA

# %%
# Separate features and target variable
X = train_df_clean_stats.drop(columns=['Label'])  # Features
y = train_df_clean_stats['Label']  # Target variable

# Initialize Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X, y)

# Select the top 30 important features
selector = SelectFromModel(rf, max_features=30, prefit=True)
selected_features = X.columns[selector.get_support()]

# Reduce the dataset to only the top 30 features
train_df_list = train_df_clean_stats[selected_features.tolist() + ['Label']]

# Print selected features
print("Top 30 selected features:", selected_features.tolist())
# Out:
# Top 30 selected features: ['Dst Port', 'Flow Duration', 'Flow Pkts/s', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Subflow Fwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts']

# %% [markdown]
# After the random forest only 11 feature met the requirements threshold and therfore these would be the selected features to train the model.

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Separate features and target using the dataset with selected features
# train_df_list is assumed to have the selected features along with the 'Label' column
X = train_df_list.drop(columns=['Label'])
y = train_df_list['Label']

# Perform PCA to reduce the data to 2 components for visualization
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X)

# Plot the PCA results
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', alpha=0.7)
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.title("PCA of Top Selected Features")
plt.legend(*scatter.legend_elements(), title="Label")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix of the dataframe containing selected features and the target label
corr_matrix = train_df_list.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Create a heat map with annotations
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)

# Add title and labels
plt.title("Correlation Heatmap of Selected Features and Label")
plt.show()

# %% [markdown]
# ---
# ## Exporting the selected features as the new training dataset

# %%
train_df_list.to_csv("selected_features.csv", index=False)
print("CSV file saved as 'selected_features.csv'")
# Out:
# CSV file saved as 'selected_features.csv'
