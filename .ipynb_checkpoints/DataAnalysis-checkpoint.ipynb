# %% [markdown]
# Import Libaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ### Compass
# definition
#
# 6 IP delivers the datagram to TCP
# If the protocol number is 17, IP delivers the datagram to UDP.

# %% [markdown]
# Read in Dataset

# %%
# Read data
original_df = pd.read_csv('sampled_data.csv')
original_df.head()
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0       443         6  14/02/2018 12:41:31      116087899            21
# 1        21         6  14/02/2018 11:13:32              1             1
# 2      3389         6  14/02/2018 02:34:56        1206036             8
# 3        53        17  14/02/2018 03:56:36           1273             1
# 4        21         6  14/02/2018 11:01:12              2             1
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0            19              750             5575              381
# 1             1                0                0                0
# 2             7             1148             1581              677
# 3             1               32               76               32
# 4             1                0                0                0
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min   Active Mean    Active Std  \
# ...

# %% [markdown]
# Var Def

# %%
Target = 'Label'

# %% [markdown]
# Split DS
# 70% training 30% rest
# 15% valid 15% test

# %%
X_classification = original_df.drop(columns=[Target])
y_classification = original_df[Target]

train_df, val_test_df = train_test_split(original_df, test_size=0.3, random_state=21)
val_df, test_df = train_test_split(val_test_df, test_size=0.5, random_state=21) 

print(f"Training set: {len(train_df)} rows")
print(f"Validation set: {len(val_df)} rows")
print(f"Testing set: {len(test_df)} rows")
# Out:
# Training set: 35000 rows
# Validation set: 7500 rows
# Testing set: 7500 rows

# %% [markdown]
# --------
# ### Date prep

# %%
print("This Dataset has {} rows and {} columns".format(train_df.shape[0], train_df.shape[1]))
# Out:
# This Dataset has 35000 rows and 80 columns

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35000 entries, 45989 to 15305
# Data columns (total 80 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           35000 non-null  int64
#  1   Protocol           35000 non-null  int64
#  2   Timestamp          35000 non-null  object
#  3   Flow Duration      35000 non-null  int64
#  4   Tot Fwd Pkts       35000 non-null  int64
#  5   Tot Bwd Pkts       35000 non-null  int64
#  6   TotLen Fwd Pkts    35000 non-null  int64
#  7   TotLen Bwd Pkts    35000 non-null  int64
#  8   Fwd Pkt Len Max    35000 non-null  int64
#  9   Fwd Pkt Len Min    35000 non-null  int64
#  10  Fwd Pkt Len Mean   35000 non-null  float64
#  11  Fwd Pkt Len Std    35000 non-null  float64
#  12  Bwd Pkt Len Max    35000 non-null  int64
#  13  Bwd Pkt Len Min    35000 non-null  int64
#  14  Bwd Pkt Len Mean   35000 non-null  float64
#  15  Bwd Pkt Len Std    35000 non-null  float64
# ...

# %%
# Drop object col.
train_df = train_df.drop("Timestamp", axis='columns')

# %%
train_df.describe()
# Out:
# /Users/ian/opt/anaconda3/envs/Diss/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# /Users/ian/opt/anaconda3/envs/Diss/lib/python3.12/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#            Dst Port      Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# count  35000.000000  35000.000000   3.500000e+04  35000.000000  35000.000000
# mean    4769.318914      7.987400  -1.135201e+07      6.562486      8.098086
# std    14308.884413      4.366157   3.642382e+09     57.351412    130.970839
# min        0.000000      0.000000  -6.814020e+11      1.000000      0.000000
# 25%       22.000000      6.000000   7.000000e+00      1.000000      1.000000
# 50%       53.000000      6.000000   9.380000e+02      2.000000      1.000000
# ...

# %% [markdown]
# There seems to be data missing therefore I tried to search for them.

# %%
print(train_df.isna().sum()) 
# print(np.isinf(train_df).sum()) not aval.
# Out:
# Dst Port         0
# Protocol         0
# Flow Duration    0
# Tot Fwd Pkts     0
# Tot Bwd Pkts     0
#                 ..
# Idle Mean        0
# Idle Std         0
# Idle Max         0
# Idle Min         0
# Label            0
# Length: 79, dtype: int64

# %% [markdown]
# Col. Timestamp and Label is propose difficulties

# %% [markdown]
# Label is an object to better train the classification model I converted to intergers.

# %%
print(train_df["Label"].dtype)
print(train_df["Label"].unique())
# Out:
# object
# ['Benign' 'FTP-BruteForce' 'SSH-Bruteforce']

# %%
train_df["Label"] = train_df["Label"].map({"Benign": 0, "FTP-BruteForce": 1, "SSH-Bruteforce": 2})

# %%
print(train_df["Label"].dtype)
print(train_df["Label"].unique())
# Out:
# int64
# [0 1 2]

# %%
train_df.head(10)
# Out:
#        Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# 45989      3389         6        1270037             8             7
# 3492        443         6       16053698            11             8
# 8311         21         6              2             1             1
# 46558     57936         6             33             2             0
# 30217        53        17          14695             1             1
# 29803       443         6       88113985            17            16
# 42076        53        17           2244             1             1
# 45541        21         6              2             1             1
# 19601        80         6       49824355             8             9
# 3831         80         6             87             2             0
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# 45989             1138             1581              677                0
# ...

# %%
missing_values = train_df.isnull().sum()
lis = missing_values[missing_values > 0]  # Filter out columns with no NaNs
print(lis)
# Out:
# Flow Byts/s    75
# dtype: int64

# %%
train_df_clean = train_df.drop(columns=["Flow Byts/s"], inplace=True)

# %%
train_df_clean = train_df
train_df_clean.head(10)
# Out:
#        Dst Port  Protocol  Flow Duration  Tot Fwd Pkts  Tot Bwd Pkts  \
# 45989      3389         6        1270037             8             7
# 3492        443         6       16053698            11             8
# 8311         21         6              2             1             1
# 46558     57936         6             33             2             0
# 30217        53        17          14695             1             1
# 29803       443         6       88113985            17            16
# 42076        53        17           2244             1             1
# 45541        21         6              2             1             1
# 19601        80         6       49824355             8             9
# 3831         80         6             87             2             0
#
#        TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  Fwd Pkt Len Min  \
# 45989             1138             1581              677                0
# ...

# %%
missing_values = train_df_clean.isnull().sum()
missing_values = missing_values[missing_values > 0]  # Filter out columns with no NaNs
print(missing_values)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# All missing vals have now been handle and all non ints have been converted.

# %%
malign = train_df_clean[train_df_clean['Label'].isin([1, 2])]
benign = train_df_clean[train_df_clean['Label'] == 0]

print('Number of DDOS attacks that has occured :',round((len(malign)/train_df_clean.shape[0])*100,2),'%')
print('Number of DDOS attacks that has not occured :',round((len(benign)/train_df_clean.shape[0])*100,2),'%')
# Out:
# Number of DDOS attacks that has occured : 38.62 %
# Number of DDOS attacks that has not occured : 61.38 %

# %% [markdown]
# Creates a bar plot

# %%
# Let's plot the Label class against the Frequency
labels = ['benign','FTP-BruteForce','SSH-Bruteforce']
classes = pd.value_counts(train_df_clean['Label'], sort = True) / train_df_clean['Label'].count() *100
classes.plot(kind = 'bar')
plt.title("Label class distribution")
plt.xticks(range(3), labels , rotation=0)
plt.xlabel("Label")
plt.ylabel("Frequency %")
# Out:
# /var/folders/4m/g_6893ld36vbb7dxvkc930h00000gp/T/ipykernel_49066/287423399.py:3: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   classes = pd.value_counts(train_df_clean['Label'], sort = True) / train_df_clean['Label'].count() *100
# Text(0, 0.5, 'Frequency %')

# %% [markdown]
# Note the dataset is extremly bias. The ML can be used to indetify, when an attack is happening. and if luckly it's a ftp or ssh brute force. Which currently no Ml sepcify in this detection.
#
# Most algo i read abt. is a general detection model but to better work with Fail2ban's jailing system, anti brute force detection a new ML detector is needed hence this project.

# %% [markdown]
# Pairplot of:
#     Dst Port (Destination port)
#     Protocol
#     Flow Duration
#     Tot Fwd Pkts (Total forward packets)
#     Tot Bwd Pkts (Total backward packets)
#     Label (Target)
# which are the important feature based on Kaggle, the source of the Data.

# %%
print(train_df_clean['Protocol'].unique())
# Out:
# [ 6 17  0]

# %% [markdown]
# 6 = TCP
# 17 = UDP
# No futhur informtation is gather about IP 0 therefore rows with 0 would be taken as N.A. and be dropped.

# %%
train_df_clean_dropIP = train_df_clean[train_df_clean['Protocol'] != 0]
print(train_df_clean_dropIP['Protocol'].unique())
# Out:
# [ 6 17]

# %%
sns.pairplot(train_df_clean_dropIP,hue="Label",vars=['Protocol','Dst Port','Flow Duration'])

# %%
train_df_clean_dropIP.columns
# Out:
# Index(['Dst Port', 'Protocol', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max',
#        'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std',
#        'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean',
#        'Bwd Pkt Len Std', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std',
#        'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean',
#        'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot',
#        'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min',
#        'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags',
#        'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s',
#        'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std',
#        'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt',
#        'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count',
# ...

# %% [markdown]
# there are currently too many cols. therefore an random forest selection is used to pick out the top 30

# %%
train_df_clean_dropIP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34605 entries, 45989 to 15305
# Data columns (total 78 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           34605 non-null  int64
#  1   Protocol           34605 non-null  int64
#  2   Flow Duration      34605 non-null  int64
#  3   Tot Fwd Pkts       34605 non-null  int64
#  4   Tot Bwd Pkts       34605 non-null  int64
#  5   TotLen Fwd Pkts    34605 non-null  int64
#  6   TotLen Bwd Pkts    34605 non-null  int64
#  7   Fwd Pkt Len Max    34605 non-null  int64
#  8   Fwd Pkt Len Min    34605 non-null  int64
#  9   Fwd Pkt Len Mean   34605 non-null  float64
#  10  Fwd Pkt Len Std    34605 non-null  float64
#  11  Bwd Pkt Len Max    34605 non-null  int64
#  12  Bwd Pkt Len Min    34605 non-null  int64
#  13  Bwd Pkt Len Mean   34605 non-null  float64
#  14  Bwd Pkt Len Std    34605 non-null  float64
#  15  Flow Pkts/s        34605 non-null  float64
# ...

# %% [markdown]
# Features such as mean, averages, max and min are causing problems with the random forest therefore it will be deleted.

# %%
# Drop columns containing 'Mean', 'Std', 'Min', or 'Max'
columns_to_drop = [col for col in train_df_clean_dropIP.columns if any(x in col for x in ["Mean", "Std", "Min", "Max","Avg"])]
train_df_clean_stats = train_df_clean_dropIP.drop(columns=columns_to_drop)

# Print the remaining columns
print("Remaining Columns:", train_df_clean_stats.columns)
# Out:
# Remaining Columns: Index(['Dst Port', 'Protocol', 'Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts',
#        'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Flow Pkts/s', 'Fwd IAT Tot',
#        'Bwd IAT Tot', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags',
#        'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s',
#        'Bwd Pkts/s', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt',
#        'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt',
#        'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Subflow Fwd Pkts',
#        'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts',
#        'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Label'],
#       dtype='object')

# %%
train_df_clean_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34605 entries, 45989 to 15305
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           34605 non-null  int64
#  1   Protocol           34605 non-null  int64
#  2   Flow Duration      34605 non-null  int64
#  3   Tot Fwd Pkts       34605 non-null  int64
#  4   Tot Bwd Pkts       34605 non-null  int64
#  5   TotLen Fwd Pkts    34605 non-null  int64
#  6   TotLen Bwd Pkts    34605 non-null  int64
#  7   Flow Pkts/s        34605 non-null  float64
#  8   Fwd IAT Tot        34605 non-null  int64
#  9   Bwd IAT Tot        34605 non-null  int64
#  10  Fwd PSH Flags      34605 non-null  int64
#  11  Bwd PSH Flags      34605 non-null  int64
#  12  Fwd URG Flags      34605 non-null  int64
#  13  Bwd URG Flags      34605 non-null  int64
#  14  Fwd Header Len     34605 non-null  int64
#  15  Bwd Header Len     34605 non-null  int64
# ...

# %%
print(train_df_clean_stats.iloc[:, [7, 16, 17, 18]])
# Out:
#           Flow Pkts/s     Fwd Pkts/s     Bwd Pkts/s    Pkt Len Var
# 45989       11.810680       6.299029       5.511650  101992.595833
# 3492         1.183528       0.685200       0.498328  175126.200000
# 8311   1000000.000000  500000.000000  500000.000000       0.000000
# 46558    60606.060606   60606.060606       0.000000       0.000000
# 30217      136.100715      68.050357      68.050357    2883.000000
# ...               ...            ...            ...            ...
# 16432     5395.683453    5395.683453       0.000000     470.250000
# 8964        41.392013      20.696007      20.696007    1470.000000
# 5944         1.357173       0.678587       0.678587    6400.777778
# 5327   1000000.000000  500000.000000  500000.000000       0.000000
# 15305  1000000.000000  500000.000000  500000.000000       0.000000
#
# [34605 rows x 4 columns]

# %%
# Check for infinity values in 'Flow Pkts/s'
print("Contains Inf:", np.isinf(train_df_clean_stats["Flow Pkts/s"]).sum())

# Check for extremely large values
print("Max Value:", train_df_clean_stats["Flow Pkts/s"].max())

# Check if any value is greater than a reasonable threshold (e.g., 1e9)
print("Values > 1e9:", (train_df_clean_stats["Flow Pkts/s"] > 1e9).sum())
# Out:
# Contains Inf: 128
# Max Value: inf
# Values > 1e9: 128

# %%
# Remove rows where "Flow Pkts/s" is infinite
train_df_clean_stats = train_df_clean_stats[~np.isinf(train_df_clean_stats["Flow Pkts/s"])]

# Reset the index after dropping rows
train_df_clean_stats.reset_index(drop=True, inplace=True)

# Confirm the issue is fixed
print("Contains Inf:", np.isinf(train_df_clean_stats["Flow Pkts/s"]).sum())  # Should print 0
print("New Max Value:", train_df_clean_stats["Flow Pkts/s"].max())  # Should be a valid number
# Out:
# Contains Inf: 0
# New Max Value: 3000000.0

# %%
train_df_clean_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34477 entries, 0 to 34476
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           34477 non-null  int64
#  1   Protocol           34477 non-null  int64
#  2   Flow Duration      34477 non-null  int64
#  3   Tot Fwd Pkts       34477 non-null  int64
#  4   Tot Bwd Pkts       34477 non-null  int64
#  5   TotLen Fwd Pkts    34477 non-null  int64
#  6   TotLen Bwd Pkts    34477 non-null  int64
#  7   Flow Pkts/s        34477 non-null  float64
#  8   Fwd IAT Tot        34477 non-null  int64
#  9   Bwd IAT Tot        34477 non-null  int64
#  10  Fwd PSH Flags      34477 non-null  int64
#  11  Bwd PSH Flags      34477 non-null  int64
#  12  Fwd URG Flags      34477 non-null  int64
#  13  Bwd URG Flags      34477 non-null  int64
#  14  Fwd Header Len     34477 non-null  int64
#  15  Bwd Header Len     34477 non-null  int64
# ...

# %%
##Code from GPT unedited
# Separate features and target variable
X = train_df_clean_stats.drop(columns=['Label'])  # Features
y = train_df_clean_stats['Label']  # Target variable

# Initialize Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X, y)

# Select the top 30 important features
selector = SelectFromModel(rf, max_features=30, prefit=True)
selected_features = X.columns[selector.get_support()]

# Reduce the dataset to only the top 30 features
train_df_list = train_df_clean_stats[selected_features.tolist() + ['Label']]

# Print selected features
print("Top 30 selected features:", selected_features.tolist())
# Out:
# Top 30 selected features: ['Dst Port', 'Flow Duration', 'Flow Pkts/s', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'PSH Flag Cnt', 'Init Fwd Win Byts', 'Fwd Act Data Pkts']

# %%
train_df_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34477 entries, 0 to 34476
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Dst Port           34477 non-null  int64
#  1   Flow Duration      34477 non-null  int64
#  2   Flow Pkts/s        34477 non-null  float64
#  3   Fwd Header Len     34477 non-null  int64
#  4   Bwd Header Len     34477 non-null  int64
#  5   Fwd Pkts/s         34477 non-null  float64
#  6   Bwd Pkts/s         34477 non-null  float64
#  7   PSH Flag Cnt       34477 non-null  int64
#  8   Init Fwd Win Byts  34477 non-null  int64
#  9   Fwd Act Data Pkts  34477 non-null  int64
#  10  Label              34477 non-null  int64
# dtypes: float64(3), int64(8)
# memory usage: 2.9 MB

# %% [markdown]
# After the random forest only 11 feature met the requirements threshold and therfore these would be the selected features to train the model.

# %%
# Save the selected columns as a CSV
train_df_list.to_csv("selected_features.csv", index=False)

print("CSV file saved as 'selected_features.csv'")
# Out:
# CSV file saved as 'selected_features.csv'
