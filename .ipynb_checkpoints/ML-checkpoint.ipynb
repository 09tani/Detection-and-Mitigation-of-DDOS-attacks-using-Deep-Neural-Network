# %% [markdown]
# # Import important Libaries

# %%
# cd Desktop/Nottingham/3rd/Dissertation/Code/Comp3003
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt

# %%
# Perform a simple matrix multiplication to test GPU usage
# This is due to tf not working on M1 chip and need to be checked. 
with tf.device('/GPU:0'):
    a = tf.random.normal([10000, 10000])
    b = tf.random.normal([10000, 10000])
    c = tf.matmul(a, b)
print(c)
# Out:
# tf.Tensor(
# [[  29.730545   -31.365026    47.81301   ...   24.452892    50.232933
#   -186.67256  ]
#  [  39.366077    64.05408     24.105465  ...    7.956687    12.825177
#    -30.748606 ]
#  [  69.6039     -89.57255     -5.4737277 ...  181.04083     27.65263
#     81.60619  ]
#  ...
#  [-247.31773     22.205719   -47.275005  ...   89.04777   -107.400986
#    -48.29427  ]
#  [  94.920944     6.6756043 -202.57756   ...   -8.195623   229.2907
#    -70.103874 ]
#  [  39.526134    23.65006   -117.487755  ...   23.599152   -19.242622
#    -16.22439  ]], shape=(10000, 10000), dtype=float32)

# %%
df = pd.read_csv('selected_features.csv')
df.head(10)
# Out:
#    Dst Port  Flow Duration     Flow Pkts/s  Fwd Header Len  Bwd Header Len  \
# 0      3389        1270037       11.810680             172             152
# 1       443       16053698        1.183528             232             172
# 2        21              2  1000000.000000              40              20
# 3     57936             33    60606.060606              40               0
# 4        53          14695      136.100715               8               8
# 5       443       88113985        0.374515             352             428
# 6        53           2244      891.265597               8               8
# 7        21              2  1000000.000000              40              20
# 8        80       49824355        0.341199             172             240
# 9        80             87    22988.505747              40               0
#
#       Fwd Pkts/s     Bwd Pkts/s  PSH Flag Cnt  Init Fwd Win Byts  \
# 0       6.299029       5.511650             1               8192
# 1       0.685200       0.498328             1               8192
# 2  500000.000000  500000.000000             1              26883
# 3   60606.060606       0.000000             0                260
# 4      68.050357      68.050357             0                 -1
# 5       0.192932       0.181583             1               8192
# 6     445.632799     445.632799             0                 -1
# 7  500000.000000  500000.000000             1              26883
# 8       0.160564       0.180635             1               8192
# 9   22988.505747       0.000000             0                278
#
#    Fwd Act Data Pkts  Label
# 0                  5      0
# 1                  5      0
# 2                  0      1
# 3                  0      0
# 4                  0      0
# 5                 11      0
# 6                  0      0
# 7                  0      1
# 8                  5      0
# 9                  0      0

# %% [markdown]
# Taking a look at how much data I have to work with.

# %%
print("This Dataset has {} rows and {} columns".format(df.shape[0], df.shape[1]))
# Out:
# This Dataset has 34477 rows and 11 columns

# %% [markdown]
# Checking that I have all the important col.

# %%
df.columns
# Out:
# Index(['Dst Port', 'Flow Duration', 'Flow Pkts/s', 'Fwd Header Len',
#        'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'PSH Flag Cnt',
#        'Init Fwd Win Byts', 'Fwd Act Data Pkts', 'Label'],
#       dtype='object')

# %% [markdown]
# Finding the unique value of each col.

# %%
print(df.apply(lambda col: col.unique()))
# Out:
# Dst Port             [3389, 443, 21, 57936, 53, 80, 58700, 22, 5259...
# Flow Duration        [1270037, 16053698, 2, 33, 14695, 88113985, 22...
# Flow Pkts/s          [11.8106795314, 1.1835279323, 1000000.0, 60606...
# Fwd Header Len       [172, 232, 40, 8, 352, 744, 60, 32, 16, 92, 71...
# Bwd Header Len       [152, 172, 20, 0, 8, 428, 240, 712, 32, 16, 92...
# Fwd Pkts/s           [6.2990290834, 0.6852003819, 500000.0, 60606.0...
# Bwd Pkts/s           [5.511650448, 0.4983275504, 500000.0, 0.0, 68....
# PSH Flag Cnt                                                    [1, 0]
# Init Fwd Win Byts    [8192, 26883, 260, -1, 278, 256, 62, 241, 6064...
# Fwd Act Data Pkts    [5, 0, 11, 16, 1, 3, 15, 6, 4, 2, 8, 12, 22, 7...
# Label                                                        [0, 1, 2]
# dtype: object

# %% [markdown]
# ### Spliting target variable from features

# %%
#separating input and output attributes
x = df.drop(['Label'], axis=1)
y = df['Label']

# %% [markdown]
# ### Normalising Variables

# %%
ms = MinMaxScaler()
x = ms.fit_transform(x)

# %% [markdown]
# ### Train-Test-Split [75-25]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.3)
print(X_train.shape, X_test.shape)
# Out:
# (24133, 10) (10344, 10)

# %% [markdown]
# # BASELINE CLASSIFIERS
#
# - DNN (Deep NN)
# - KNN
# - SVM
# - Decision tree
# - Naive Bayes
# - Quadratic Discriminant Analaysis
# - SGD
# - Logistic Regression
# - XGBoost

# %%
Classifier_accuracy = []

# %% [markdown]
# ### Defining the Deep Neural Network

# %%
# Define and compile model
model = keras.Sequential()
model.add(Dense(28 , input_shape=(10,) , activation="relu" , name="Hidden_Layer_1"))
model.add(Dense(10 , activation="relu" , name="Hidden_Layer_2"))
model.add(Dense(1 , activation="sigmoid" , name="Output_Layer"))
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile( optimizer=opt, loss="binary_crossentropy", metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden_Layer_1 (Dense)      (None, 28)                308
#
#  Hidden_Layer_2 (Dense)      (None, 10)                290
#
#  Output_Layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 609
# Trainable params: 609
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model Fitting

# %%
# fit model
history_org = model.fit(
    X_train, 
    y_train, 
    batch_size=32, 
    epochs=10, verbose=2, 
    # 要跑多少遍你就调epochs
    callbacks=None, 
    validation_data=(X_test,y_test), 
    shuffle=True, 
    class_weight=None, 
    sample_weight=None, 
    initial_epoch=0)
# Out:
# Epoch 1/100
# 2025-02-22 14:52:55.130494: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2025-02-22 14:52:55.187484: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignAddVariableOp_10.
# 2025-02-22 14:53:03.960860: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 755/755 - 11s - loss: -1.3243e+03 - accuracy: 0.6730 - val_loss: -5.6679e+03 - val_accuracy: 0.6584 - 11s/epoch - 14ms/step
# Epoch 2/100
# 755/755 - 8s - loss: -2.1625e+04 - accuracy: 0.6795 - val_loss: -4.4671e+04 - val_accuracy: 0.7025 - 8s/epoch - 10ms/step
# Epoch 3/100
# 755/755 - 7s - loss: -8.6514e+04 - accuracy: 0.6799 - val_loss: -1.3475e+05 - val_accuracy: 0.6913 - 7s/epoch - 10ms/step
# Epoch 4/100
# 755/755 - 8s - loss: -2.0890e+05 - accuracy: 0.6789 - val_loss: -2.8674e+05 - val_accuracy: 0.6967 - 8s/epoch - 10ms/step
# Epoch 5/100
# 755/755 - 8s - loss: -3.9836e+05 - accuracy: 0.6792 - val_loss: -5.0857e+05 - val_accuracy: 0.6670 - 8s/epoch - 11ms/step
# Epoch 6/100
# 755/755 - 8s - loss: -6.6030e+05 - accuracy: 0.6801 - val_loss: -8.0042e+05 - val_accuracy: 0.6787 - 8s/epoch - 10ms/step
# Epoch 7/100
# 755/755 - 8s - loss: -9.9767e+05 - accuracy: 0.6799 - val_loss: -1.1704e+06 - val_accuracy: 0.6468 - 8s/epoch - 10ms/step
# Epoch 8/100
# 755/755 - 7s - loss: -1.4155e+06 - accuracy: 0.6793 - val_loss: -1.6223e+06 - val_accuracy: 0.6846 - 7s/epoch - 10ms/step
# Epoch 9/100
# 755/755 - 8s - loss: -1.9187e+06 - accuracy: 0.6802 - val_loss: -2.1628e+06 - val_accuracy: 0.6628 - 8s/epoch - 10ms/step
# Epoch 10/100
# 755/755 - 7s - loss: -2.5218e+06 - accuracy: 0.6786 - val_loss: -2.8061e+06 - val_accuracy: 0.6842 - 7s/epoch - 10ms/step
# Epoch 11/100
# 755/755 - 7s - loss: -3.2309e+06 - accuracy: 0.6795 - val_loss: -3.5526e+06 - val_accuracy: 0.6877 - 7s/epoch - 10ms/step
# Epoch 12/100
# 755/755 - 8s - loss: -4.0430e+06 - accuracy: 0.6801 - val_loss: -4.4065e+06 - val_accuracy: 0.6823 - 8s/epoch - 10ms/step
# Epoch 13/100
# 755/755 - 8s - loss: -4.9727e+06 - accuracy: 0.6788 - val_loss: -5.3752e+06 - val_accuracy: 0.6845 - 8s/epoch - 10ms/step
# Epoch 14/100
# 755/755 - 7s - loss: -6.0181e+06 - accuracy: 0.6795 - val_loss: -6.4580e+06 - val_accuracy: 0.6737 - 7s/epoch - 10ms/step
# Epoch 15/100
# 755/755 - 7s - loss: -7.1847e+06 - accuracy: 0.6796 - val_loss: -7.6647e+06 - val_accuracy: 0.6860 - 7s/epoch - 10ms/step
# Epoch 16/100
# 755/755 - 7s - loss: -8.4822e+06 - accuracy: 0.6792 - val_loss: -8.9970e+06 - val_accuracy: 0.6918 - 7s/epoch - 10ms/step
# Epoch 17/100
# 755/755 - 7s - loss: -9.9139e+06 - accuracy: 0.6798 - val_loss: -1.0477e+07 - val_accuracy: 0.6903 - 7s/epoch - 10ms/step
# Epoch 18/100
# 755/755 - 7s - loss: -1.1498e+07 - accuracy: 0.6804 - val_loss: -1.2115e+07 - val_accuracy: 0.6869 - 7s/epoch - 9ms/step
# Epoch 19/100
# 755/755 - 7s - loss: -1.3238e+07 - accuracy: 0.6797 - val_loss: -1.3890e+07 - val_accuracy: 0.6962 - 7s/epoch - 9ms/step
# Epoch 20/100
# 755/755 - 7s - loss: -1.5131e+07 - accuracy: 0.6806 - val_loss: -1.5821e+07 - val_accuracy: 0.6901 - 7s/epoch - 10ms/step
# Epoch 21/100
# 755/755 - 7s - loss: -1.7182e+07 - accuracy: 0.6803 - val_loss: -1.7906e+07 - val_accuracy: 0.6982 - 7s/epoch - 10ms/step
# Epoch 22/100
# 755/755 - 7s - loss: -1.9395e+07 - accuracy: 0.6817 - val_loss: -2.0181e+07 - val_accuracy: 0.6854 - 7s/epoch - 10ms/step
# Epoch 23/100
# 755/755 - 7s - loss: -2.1800e+07 - accuracy: 0.6801 - val_loss: -2.2622e+07 - val_accuracy: 0.6912 - 7s/epoch - 10ms/step
# Epoch 24/100
# 755/755 - 7s - loss: -2.4387e+07 - accuracy: 0.6811 - val_loss: -2.5245e+07 - val_accuracy: 0.6863 - 7s/epoch - 10ms/step
# Epoch 25/100
# 755/755 - 7s - loss: -2.7140e+07 - accuracy: 0.6813 - val_loss: -2.8051e+07 - val_accuracy: 0.6770 - 7s/epoch - 10ms/step
# Epoch 26/100
# 755/755 - 7s - loss: -3.0106e+07 - accuracy: 0.6810 - val_loss: -3.1064e+07 - val_accuracy: 0.6695 - 7s/epoch - 10ms/step
# Epoch 27/100
# 755/755 - 7s - loss: -3.3272e+07 - accuracy: 0.6799 - val_loss: -3.4260e+07 - val_accuracy: 0.6875 - 7s/epoch - 10ms/step
# Epoch 28/100
# 755/755 - 7s - loss: -3.6635e+07 - accuracy: 0.6811 - val_loss: -3.7659e+07 - val_accuracy: 0.6853 - 7s/epoch - 10ms/step
# Epoch 29/100
# 755/755 - 7s - loss: -4.0216e+07 - accuracy: 0.6809 - val_loss: -4.1293e+07 - val_accuracy: 0.6761 - 7s/epoch - 10ms/step
# Epoch 30/100
# 755/755 - 7s - loss: -4.4017e+07 - accuracy: 0.6801 - val_loss: -4.5111e+07 - val_accuracy: 0.6868 - 7s/epoch - 10ms/step
# Epoch 31/100
# 755/755 - 7s - loss: -4.8027e+07 - accuracy: 0.6810 - val_loss: -4.9161e+07 - val_accuracy: 0.6653 - 7s/epoch - 10ms/step
# Epoch 32/100
# 755/755 - 7s - loss: -5.2235e+07 - accuracy: 0.6815 - val_loss: -5.3392e+07 - val_accuracy: 0.6746 - 7s/epoch - 10ms/step
# Epoch 33/100
# 755/755 - 7s - loss: -5.6697e+07 - accuracy: 0.6808 - val_loss: -5.7868e+07 - val_accuracy: 0.6752 - 7s/epoch - 10ms/step
# Epoch 34/100
# 755/755 - 7s - loss: -6.1373e+07 - accuracy: 0.6810 - val_loss: -6.2586e+07 - val_accuracy: 0.6868 - 7s/epoch - 10ms/step
# Epoch 35/100
# 755/755 - 7s - loss: -6.6317e+07 - accuracy: 0.6818 - val_loss: -6.7576e+07 - val_accuracy: 0.6644 - 7s/epoch - 10ms/step
# Epoch 36/100
# 755/755 - 7s - loss: -7.1541e+07 - accuracy: 0.6804 - val_loss: -7.2839e+07 - val_accuracy: 0.6837 - 7s/epoch - 10ms/step
# Epoch 37/100
# 755/755 - 7s - loss: -7.7018e+07 - accuracy: 0.6820 - val_loss: -7.8302e+07 - val_accuracy: 0.6828 - 7s/epoch - 10ms/step
# Epoch 38/100
# 755/755 - 7s - loss: -8.2707e+07 - accuracy: 0.6818 - val_loss: -8.4023e+07 - val_accuracy: 0.6699 - 7s/epoch - 10ms/step
# Epoch 39/100
# 755/755 - 7s - loss: -8.8645e+07 - accuracy: 0.6816 - val_loss: -8.9948e+07 - val_accuracy: 0.6740 - 7s/epoch - 10ms/step
# Epoch 40/100
# 755/755 - 7s - loss: -9.4860e+07 - accuracy: 0.6804 - val_loss: -9.6252e+07 - val_accuracy: 0.6848 - 7s/epoch - 10ms/step
# Epoch 41/100
# 755/755 - 7s - loss: -1.0144e+08 - accuracy: 0.6809 - val_loss: -1.0275e+08 - val_accuracy: 0.6934 - 7s/epoch - 10ms/step
# Epoch 42/100
# 755/755 - 7s - loss: -1.0825e+08 - accuracy: 0.6830 - val_loss: -1.0958e+08 - val_accuracy: 0.6819 - 7s/epoch - 10ms/step
# Epoch 43/100
# 755/755 - 7s - loss: -1.1527e+08 - accuracy: 0.6809 - val_loss: -1.1668e+08 - val_accuracy: 0.6878 - 7s/epoch - 10ms/step
# Epoch 44/100
# Epoch 80/100
# 755/755 - 7s - loss: -6.3786e+08 - accuracy: 0.6823 - val_loss: -6.3650e+08 - val_accuracy: 0.6729 - 7s/epoch - 10ms/step
# Epoch 81/100
# 755/755 - 7s - loss: -6.6052e+08 - accuracy: 0.6822 - val_loss: -6.5893e+08 - val_accuracy: 0.6860 - 7s/epoch - 10ms/step
# Epoch 82/100
# 755/755 - 7s - loss: -6.8369e+08 - accuracy: 0.6814 - val_loss: -6.8203e+08 - val_accuracy: 0.6863 - 7s/epoch - 10ms/step
# Epoch 83/100
# 755/755 - 7s - loss: -7.0753e+08 - accuracy: 0.6821 - val_loss: -7.0567e+08 - val_accuracy: 0.6803 - 7s/epoch - 10ms/step
# Epoch 84/100
# 755/755 - 7s - loss: -7.3187e+08 - accuracy: 0.6805 - val_loss: -7.2981e+08 - val_accuracy: 0.6728 - 7s/epoch - 9ms/step
# Epoch 85/100
# 755/755 - 7s - loss: -7.5658e+08 - accuracy: 0.6817 - val_loss: -7.5413e+08 - val_accuracy: 0.6821 - 7s/epoch - 9ms/step
# Epoch 86/100
# 755/755 - 7s - loss: -7.8178e+08 - accuracy: 0.6819 - val_loss: -7.7894e+08 - val_accuracy: 0.6846 - 7s/epoch - 10ms/step
# Epoch 87/100
# 755/755 - 7s - loss: -8.0723e+08 - accuracy: 0.6805 - val_loss: -8.0440e+08 - val_accuracy: 0.6886 - 7s/epoch - 10ms/step
# Epoch 88/100
# 755/755 - 7s - loss: -8.3359e+08 - accuracy: 0.6831 - val_loss: -8.3044e+08 - val_accuracy: 0.6730 - 7s/epoch - 10ms/step
# Epoch 89/100
# 755/755 - 7s - loss: -8.6055e+08 - accuracy: 0.6807 - val_loss: -8.5710e+08 - val_accuracy: 0.6841 - 7s/epoch - 10ms/step
# Epoch 90/100
# 755/755 - 7s - loss: -8.8796e+08 - accuracy: 0.6821 - val_loss: -8.8430e+08 - val_accuracy: 0.6829 - 7s/epoch - 10ms/step
# Epoch 91/100
# 755/755 - 7s - loss: -9.1598e+08 - accuracy: 0.6817 - val_loss: -9.1204e+08 - val_accuracy: 0.6804 - 7s/epoch - 10ms/step
# Epoch 92/100
# 755/755 - 8s - loss: -9.4460e+08 - accuracy: 0.6813 - val_loss: -9.4024e+08 - val_accuracy: 0.6835 - 8s/epoch - 10ms/step
# Epoch 93/100
# 755/755 - 7s - loss: -9.7352e+08 - accuracy: 0.6816 - val_loss: -9.6882e+08 - val_accuracy: 0.6841 - 7s/epoch - 10ms/step
# Epoch 94/100
# 755/755 - 7s - loss: -1.0030e+09 - accuracy: 0.6822 - val_loss: -9.9811e+08 - val_accuracy: 0.6804 - 7s/epoch - 10ms/step
# Epoch 95/100
# 755/755 - 7s - loss: -1.0331e+09 - accuracy: 0.6826 - val_loss: -1.0279e+09 - val_accuracy: 0.6709 - 7s/epoch - 10ms/step
# Epoch 96/100
# 755/755 - 7s - loss: -1.0637e+09 - accuracy: 0.6806 - val_loss: -1.0582e+09 - val_accuracy: 0.6864 - 7s/epoch - 10ms/step
# Epoch 97/100
# 755/755 - 7s - loss: -1.0951e+09 - accuracy: 0.6833 - val_loss: -1.0894e+09 - val_accuracy: 0.6706 - 7s/epoch - 10ms/step
# Epoch 98/100
# 755/755 - 7s - loss: -1.1273e+09 - accuracy: 0.6812 - val_loss: -1.1211e+09 - val_accuracy: 0.6837 - 7s/epoch - 10ms/step
# Epoch 99/100
# 755/755 - 7s - loss: -1.1600e+09 - accuracy: 0.6823 - val_loss: -1.1534e+09 - val_accuracy: 0.6869 - 7s/epoch - 10ms/step
# Epoch 100/100
# 755/755 - 7s - loss: -1.1935e+09 - accuracy: 0.6821 - val_loss: -1.1869e+09 - val_accuracy: 0.6802 - 7s/epoch - 9ms/step

# %% [markdown]
# ### Plotting Loss v/s Epochs

# %%
loss = history_org.history['loss']
val_loss = history_org.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g', label = 'Training Loss')
plt.plot(epochs, val_loss, 'r', label = 'Validation Loss')
plt.title('Loss v/s No. of epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Plotting Accuracy v/s Epochs

# %%
loss = history_org.history['accuracy']
val_loss = history_org.history['val_accuracy']
plt.plot(epochs, loss, 'g', label = 'Training accuracy')
plt.plot(epochs, val_loss, 'r', label = 'Validation accuracy')
plt.title('Accuracy Scores v/s Number of Epochs')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy of Deep neural Network : %.2f' % (accuracy*100))
Classifier_accuracy.append(accuracy*100)
# Out:
# 324/324 [==============================] - 2s 5ms/step - loss: -1186891776.0000 - accuracy: 0.6802
# Accuracy of Deep neural Network : 68.02

# %%
## Model Evaluation

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Accuracy of Deep neural Network : %.2f' % (accuracy*100))
Classifier_accuracy.append(accuracy*100)
# Out:
# 324/324 [==============================] - 2s 6ms/step - loss: -1186891776.0000 - accuracy: 0.6802
# Accuracy of Deep neural Network : 68.02

# %%
#K-Nearest Neighbor Classifier

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_train)
y_pred = knn_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of KNN Classifier : %.2f" % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 knn_clf = KNeighborsClassifier()
#       2 knn_clf.fit(X_train, y_train)
#       3 y_pred = knn_clf.predict(X_test)
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
SVM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 SVM
#
# NameError: name 'SVM' is not defined

# %%
svc_clf = SVC() 
svc_clf.fit(X_train,y_train)
y_pred = svc_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of SVM Classifier : %.2f" % (accuracy*100) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 svc_clf = SVC()
#       2 svc_clf.fit(X_train,y_train)
#       3 y_pred = svc_clf.predict(X_test)
#
# NameError: name 'SVC' is not defined

# %%
Decision Tree Classifier
# Out:
#   Cell In[38], line 1
#     Decision Tree Classifier
#              ^
# SyntaxError: invalid syntax

# %%
dt_clf = DecisionTreeClassifier(max_depth=5)
dt_clf.fit(X_train,y_train)
y_pred = dt_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Decision Tree Classifier : %.2f" % (accuracy*100) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dt_clf = DecisionTreeClassifier(max_depth=5)
#       2 dt_clf.fit(X_train,y_train)
#       3 y_pred = dt_clf.predict(X_test)
#
# NameError: name 'DecisionTreeClassifier' is not defined

# %%
Naive Bayes Classifier
# Out:
#   Cell In[40], line 1
#     Naive Bayes Classifier
#           ^
# SyntaxError: invalid syntax

# %%
nb_clf = CategoricalNB()
nb_clf.fit(X_train,y_train)
y_pred = nb_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Naive Bayes Classifier : %.2f" % (accuracy*100) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 nb_clf = CategoricalNB()
#       2 nb_clf.fit(X_train,y_train)
#       3 y_pred = nb_clf.predict(X_test)
#
# NameError: name 'CategoricalNB' is not defined

# %%
	
Stochastic Gradient Classifier
# Out:
#   Cell In[42], line 1
#     Stochastic Gradient Classifier
#                ^
# SyntaxError: invalid syntax

# %%
sgd_clf=SGDClassifier(loss="hinge", penalty="l2")
sgd_clf.fit(X_train,y_train)
y_pred=sgd_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of SGD Classifier : %.2f" % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sgd_clf=SGDClassifier(loss="hinge", penalty="l2")
#       2 sgd_clf.fit(X_train,y_train)
#       3 y_pred=sgd_clf.predict(X_test)
#
# NameError: name 'SGDClassifier' is not defined

# %%
Logistic Regression
# Out:
#   Cell In[44], line 1
#     Logistic Regression
#              ^
# SyntaxError: invalid syntax

# %%
lr_clf = LogisticRegression()
lr_clf.fit(X_train,y_train)
y_pred=lr_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of Logistic Regression Classifier : %.2f" % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 lr_clf = LogisticRegression()
#       2 lr_clf.fit(X_train,y_train)
#       3 y_pred=lr_clf.predict(X_test)
#
# NameError: name 'LogisticRegression' is not defined

# %%
XGBoost Classifier
# Out:
#   Cell In[46], line 1
#     XGBoost Classifier
#             ^
# SyntaxError: invalid syntax

# %%
xgb_clf=xgb.XGBClassifier(eval_metric = 'error',objective='binary:logistic',max_depth=2, learning_rate=0.1)
xgb_clf.fit(X_train,y_train)
y_pred=xgb_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of XGBoost Classifier : %.2f" % (accuracy*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 xgb_clf=xgb.XGBClassifier(eval_metric = 'error',objective='binary:logistic',max_depth=2, learning_rate=0.1)
#       2 xgb_clf.fit(X_train,y_train)
#       3 y_pred=xgb_clf.predict(X_test)
#
# NameError: name 'xgb' is not defined

# %%
Comparitive analysis of models
# Out:
#   Cell In[48], line 1
#     Comparitive analysis of models
#                 ^
# SyntaxError: invalid syntax

# %%
Classifier_names = ["DNN", "KNN", "RBF_SVM", "Decision Tree","Naive Bayes","Quadratic","SGD","Logistic Regression","XGBoost"]

# %%
df_clf = pd.DataFrame()
df_clf['name'] = Classifier_names
df_clf['Accuracy'] = Classifier_accuracy
df_clf = df_clf.sort_values(by=['Accuracy'], ascending=False)
df_clf.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 3
#       1 df_clf = pd.DataFrame()
#       2 df_clf['name'] = Classifier_names
# ----> 3 df_clf['Accuracy'] = Classifier_accuracy
#       4 df_clf = df_clf.sort_values(by=['Accuracy'], ascending=False)
#       5 df_clf.head(10)
#
# File ~/opt/anaconda3/envs/Dissertation/lib/python3.9/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/opt/anaconda3/envs/Dissertation/lib/python3.9/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/opt/anaconda3/envs/Dissertation/lib/python3.9/site-packages/pandas/core/frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~/opt/anaconda3/envs/Dissertation/lib/python3.9/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (2) does not match length of index (9)

# %%
Visualize accuracies of the models
# Out:
#   Cell In[51], line 1
#     Visualize accuracies of the models
#               ^
# SyntaxError: invalid syntax

# %%
sns.set(style="whitegrid",rc={'figure.figsize':(7,7)})
ax = sns.barplot(y="name", x="Accuracy", data=df_clf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sns.set(style="whitegrid",rc={'figure.figsize':(7,7)})
#       2 ax = sns.barplot(y="name", x="Accuracy", data=df_clf)
#
# NameError: name 'sns' is not defined

# %%
print(f"The best baseline Classifier is {df_clf.name[0]} with an accuracy of {df_clf.Accuracy[0]}.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4m/g_6893ld36vbb7dxvkc930h00000gp/T/ipykernel_76714/981369497.py in ?()
# ----> 1 print(f"The best baseline Classifier is {df_clf.name[0]} with an accuracy of {df_clf.Accuracy[0]}.")
#
# ~/opt/anaconda3/envs/Dissertation/lib/python3.9/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Accuracy'

# %%
Hyperparameter tuning
# Out:
#   Cell In[54], line 1
#     Hyperparameter tuning
#                    ^
# SyntaxError: invalid syntax
