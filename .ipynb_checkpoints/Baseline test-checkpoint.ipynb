# %% [markdown]
# # Import Libaries including numpy and sklearn

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn import metrics

# %% [markdown]
# # Read in the data frame

# %%
df = pd.read_csv('sampled_data.csv')
df.head()
# Out:
#    Dst Port  Protocol            Timestamp  Flow Duration  Tot Fwd Pkts  \
# 0       443         6  14/02/2018 12:41:31      116087899            21
# 1        21         6  14/02/2018 11:13:32              1             1
# 2      3389         6  14/02/2018 02:34:56        1206036             8
# 3        53        17  14/02/2018 03:56:36           1273             1
# 4        21         6  14/02/2018 11:01:12              2             1
#
#    Tot Bwd Pkts  TotLen Fwd Pkts  TotLen Bwd Pkts  Fwd Pkt Len Max  \
# 0            19              750             5575              381
# 1             1                0                0                0
# 2             7             1148             1581              677
# 3             1               32               76               32
# 4             1                0                0                0
#
#    Fwd Pkt Len Min  ...  Fwd Seg Size Min   Active Mean    Active Std  \
# ...

# %%
df.shape
# Out:
# (49434, 78)

# %% [markdown]
# ## Drop object timestamp and Encode Label

# %%
df = df.drop("Timestamp", axis=1)
df["Label"] = df["Label"].map({"Benign": 0, "FTP-BruteForce": 1, "SSH-Bruteforce": 2})

# %% [markdown]
# ## Remove IP 0 - reason explain in paper

# %%
df.drop(columns=["Flow Byts/s"], inplace=True)
df = df[df['Protocol'] != 0]

# %% [markdown]
# ## Check for negative vals and remove them

# %%
df_cleaned = df[(df >= 0).all(axis=1)]

# %% [markdown]
# ## Check for infinite vals and remove them

# %%
inf_check = df_cleaned.isin([np.inf, -np.inf]).any()
columns_with_inf = inf_check[inf_check].index.tolist()
print("Columns with infinities:", columns_with_inf)
# Out:
# Columns with infinities: ['Flow Pkts/s']

# %%
# Replace inf/-inf with NaN and drop rows
df_cleaned = df_cleaned.replace([np.inf, -np.inf], np.nan).dropna()
print("Remaining infinities in df_cleaned:", np.isinf(df_cleaned).any().any())
# Out:
# Remaining infinities in df_cleaned: False

# %% [markdown]
# # Scale the data using standard scaling

# %%
scaler = StandardScaler()
df_cleaned_scaled = scaler.fit_transform(df_cleaned)

# %%
x = df_cleaned.drop(['Label'], axis=1)
y = df_cleaned['Label']
print(y.unique())
# Out:
# [0 1 2]

# %% [markdown]
# ## Split the data into train and test

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size = 0.9)

# %%
X_train.nunique()
# Out:
# Dst Port          197
# Protocol            1
# Flow Duration    1828
# Tot Fwd Pkts       55
# Tot Bwd Pkts       66
#                  ...
# Active Min        356
# Idle Mean         361
# Idle Std          271
# Idle Max          361
# Idle Min          361
# Length: 77, dtype: int64

# %% [markdown]
# ### Defined accuracy as an array

# %%
Classifier_accuracy = []

# %% [markdown]
# # Building the KNN model using Sklearn package

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_train)
y_pred = knn_clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
Classifier_accuracy.append(accuracy*100)
print("Accuracy of KNN Classifier : %.2f" % (accuracy*100))
# Out:
# Accuracy of KNN Classifier : 9.93

# %% [markdown]
# ### Achieved an incredible accruracy of 99.79%
#
# Potential over fitting porblem that could be solve by creating a more conplex model, Deep Neural Network.

# %% [markdown]
# ## Created a clssification matrix to identify for potential overfiting problem

# %%
# Define class names as strings in the order of numeric labels
labels = ['0', '1', '2']  # Replace with your actual class names

print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     13281
#            1       0.99      1.00      1.00      8803
#            2       0.98      1.00      0.99      8528
#
#     accuracy                           0.99     30612
#    macro avg       0.99      0.99      0.99     30612
# weighted avg       0.99      0.99      0.99     30612

# %% [markdown]
# ## SVM

# %%
# Create the SVM classifier (using default parameters)
svm_clf = SVC()

# Fit the model using the training data
svm_clf.fit(X_train, y_train)

# Predict labels for the test data
y_pred_svm = svm_clf.predict(X_test)

# Calculate accuracy
accuracy_svm = metrics.accuracy_score(y_test, y_pred_svm)

# Append the accuracy (scaled as in your KNN example)
Classifier_accuracy.append(accuracy_svm * 100)

print("Accuracy of SVM Classifier : %.2f" % (accuracy_svm * 100))
# Out:
# Accuracy of SVM Classifier : 76.33

# %%
# Create the Gaussian Naive Bayes classifier
nb_clf = GaussianNB()

# Fit the model using the training data
nb_clf.fit(X_train, y_train)

# Predict labels for the test data
y_pred_nb = nb_clf.predict(X_test)

# Calculate accuracy
accuracy_nb = metrics.accuracy_score(y_test, y_pred_nb)

# Append the accuracy (scaled as in your KNN example)
Classifier_accuracy.append(accuracy_nb * 100)

print("Accuracy of Naive Bayes Classifier : %.2f" % (accuracy_nb * 100))
# Out:
# Accuracy of Naive Bayes Classifier : 93.65
